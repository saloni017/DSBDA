# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.drop('deck',axis=1,inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
sns.scatterplot(x='age',y='fare',data=df)
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.histplot(data=df)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data=df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.displot(df,x='fare',binwidth=50)

# %%
sns.displot(df,x='pclass')

# %%
sns.displot(df,x='adult_male')

# %%
sns.displot(df,x='sibsp')

# %%
sns.displot(df,x='parch')

# %%
sns.displot(df,x='survived')

# %%
sns.displot(df,x='fare',col='sex',binwidth=50)

# %%
sns.displot(df,x='fare',col='pclass',binwidth=50)

# %%
sns.displot(df,x='fare',col='survived',binwidth=50)

# %%
sns.barplot(x='sex',y='age',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.catplot(x='embarked',hue='survived',kind='count',col='pclass',data=df)

# %%
sns.catplot(x='embarked',hue='survived',kind='bar',col='pclass',data=df)

# %%
sns.catplot(x='survived',hue='embarked',kind='bar',col='pclass',data=df)

# %%
sns.stripplot(x='sex',y='age',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stri
